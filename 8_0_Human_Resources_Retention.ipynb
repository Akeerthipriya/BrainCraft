# %% [markdown]
# <a href="https://colab.research.google.com/github/Akeerthipriya/BrainCraft/blob/master/8_0_Human_Resources_Retention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retention Study - Figuring Out Which Employees May Quit
# ### Loading our Main HR Database Records

# %%
import pandas as pd

# Uncomment this line if using this notebook locally
#hr_df = pd.read_csv('./data/employee_retention/hr_data.csv') 

file_name = "/content/hr_data.csv"
hr_df = pd.read_csv(file_name)

# We use the dataframe name followed by a '.head()' to use the head function to 
# preview the first 5 records of the dataframe. If you wanted to preview the first 10, simply 
# put dataframe_name.head(10)
hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
# View the bottom 5 rows
hr_df.tail()
# Out:
#        employee_id  number_project  ...  department  salary
# 14994        87670               2  ...     support     low
# 14995        87673               2  ...     support     low
# 14996        87679               2  ...     support     low
# 14997        87681               6  ...     support     low
# 14998        87684               2  ...     support     low
#
# [5 rows x 9 columns]

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
# View which columns are categorical
hr_df.select_dtypes(exclude=['int', 'float']).columns
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
# Display values in categorical columns
print(hr_df['department'].unique())
print(hr_df['salary'].unique())
# Out:
# ['sales' 'accounting' 'hr' 'technical' 'support' 'management' 'IT'
#  'product_mng' 'marketing' 'RandD']
# ['low' 'medium' 'high']

# %%
# How many rows are in our dataset?
len(hr_df)
# Out:
# 14999

# %%
# What about how many columns?
len(hr_df.columns)
# Out:
# 9

# %%
hr_df.shape
# Out:
# (14999, 9)

# %% [markdown]
# ### Loading our Evaluation and Employee Satisfaction Data

# %%
# Uncomment this line if using this notebook locally
#emp_satis_eval = pd.read_excel ('./data/employee_retention/employee_satisfaction_evaluation.xlsx') 

file_name = "/content/employee_satisfaction_evaluation.xlsx"
emp_satis_eval = pd.read_excel(file_name)

emp_satis_eval.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
emp_satis_eval.shape
# Out:
# (14999, 3)

# %% [markdown]
# ### Merge or Join Tables

# %%
main_df = hr_df.set_index('employee_id').join(emp_satis_eval.set_index('EMPLOYEE #'))
main_df = main_df.reset_index()
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Is our dataset good? Are there missing values?

# %%
#main_df.isnull()
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18            3794               2  ...                 NaN              NaN
# 19            1140               5  ...                 NaN             0.89
# 33            1230               2  ...                 NaN              NaN
# 53            1340               2  ...                 NaN              NaN
# 72           22316               2  ...                 NaN              NaN
# 92            1581               2  ...                 NaN              NaN
# 107          17376               2  ...                 NaN              NaN
# 120           1739               4  ...                 NaN              NaN
# 137           1847               2  ...                 NaN              NaN
# 175          32923               4  ...                 NaN              NaN
# 191           2160               4  ...                0.92              NaN
# 352           3150               4  ...                 NaN             0.91
# 376           3250               4  ...                0.56              NaN
# 402           3405               5  ...                 NaN             1.00
# 427          78130               3  ...                 NaN             0.60
# 442           3635               5  ...                0.77              NaN
# 468           3755               5  ...                 NaN             0.92
# 543           4150               5  ...                0.89              NaN
# 892          43615               4  ...                0.74              NaN
# 1588         42185               5  ...                 NaN             0.81
# 1934         11895               4  ...                0.78              NaN
# 2343         14170               3  ...                 NaN             0.97
# 2743         16445               5  ...                0.62              NaN
# 3170         18980               5  ...                 NaN              NaN
# 3609         21580               3  ...                0.95              NaN
# 3776         22555               4  ...                 NaN             0.68
# 4122         24505               3  ...                0.86              NaN
# 4740         27950               3  ...                 NaN             0.95
# 5028         29640               4  ...                0.64              NaN
# 6453         38090               5  ...                 NaN             0.78
# 7005         41535               4  ...                0.82              NaN
# 7516         44460               4  ...                 NaN             0.97
# 8630         50960               4  ...                0.90              NaN
# 9455         55770               4  ...                 NaN             0.88
# 9901         58630               5  ...                0.92              NaN
# 10647        62595               4  ...                 NaN             0.69
# 10962        64350               5  ...                0.65              NaN
# 11575        20215               3  ...                 NaN              NaN
# 11967        70005               3  ...                0.82              NaN
# 12422        72475               5  ...                 NaN             1.00
# 12853        74880               3  ...                 NaN             0.70
# 13482        78780               3  ...                0.58              NaN
# 13925        81315               3  ...                 NaN             0.75
#
# [43 rows x 11 columns]

# %% [markdown]
# ### Let's fill in the missing blanks with the aveage values

# %%
main_df.describe()
# Out:
#         employee_id  number_project  ...  satisfaction_level  last_evaluation
# count  14999.000000    14999.000000  ...        14972.000000     14972.000000
# mean   45424.627575        3.803054  ...            0.612830         0.716125
# std    25915.900127        1.232592  ...            0.248714         0.171138
# min     1003.000000        2.000000  ...            0.090000         0.360000
# 25%    22872.500000        3.000000  ...            0.440000         0.560000
# 50%    45448.000000        4.000000  ...            0.640000         0.720000
# 75%    67480.500000        5.000000  ...            0.820000         0.870000
# max    99815.000000        7.000000  ...            1.000000         1.000000
#
# [8 rows x 9 columns]

# %%
main_df.fillna(main_df.mean(), inplace=True)
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
#main_df[main_df.employee_id == 3794]
main_df.loc[main_df['employee_id'] == 3794]
# Out:
#     employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18         3794               2  ...             0.61283         0.716125
#
# [1 rows x 11 columns]

# %%
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
# Removing employee ID
main_df_final = main_df.drop(columns='employee_id')
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  satisfaction_level  last_evaluation
# 0               2                   157  ...                0.38             0.53
# 1               5                   262  ...                0.80             0.86
# 2               7                   272  ...                0.11             0.88
# 3               5                   223  ...                0.72             0.87
# 4               2                   159  ...                0.37             0.52
#
# [5 rows x 10 columns]

# %%
main_df_final.groupby('department').sum()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                     4683  ...       879.452250
# RandD                  3033  ...       560.446125
# accounting             2934  ...       550.706125
# hr                     2701  ...       524.006125
# management             2432  ...       456.234499
# marketing              3164  ...       613.946125
# product_mng            3434  ...       644.662250
# sales                 15634  ...      2938.236749
# support                8479  ...      1611.534499
# technical             10548  ...      1961.930624
#
# [10 rows x 8 columns]

# %%
main_df_final.groupby('department').mean()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                 3.816626  ...         0.716750
# RandD              3.853875  ...         0.712130
# accounting         3.825293  ...         0.718000
# hr                 3.654939  ...         0.709075
# management         3.860317  ...         0.724182
# marketing          3.687646  ...         0.715555
# product_mng        3.807095  ...         0.714703
# sales              3.776329  ...         0.709719
# support            3.803948  ...         0.722985
# technical          3.877941  ...         0.721298
#
# [10 rows x 8 columns]

# %%
main_df_final['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
main_df_final['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# ### Displaying Your Correlation Matrix

# %%
import matplotlib.pyplot as plt

def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.legend()
    cax = ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    
plot_corr(main_df_final)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Preparing out  Dataset for ML

# %%
# Perform One Hot Encoding on Categorical Data
categorial = ['department','salary']
main_df_final = pd.get_dummies(main_df_final, columns=categorial, drop_first=True)
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %%
# How many columns do we now have?

len(main_df_final.columns)
# Out:
# 19

# %%
# How many employees in the dataset have left?

len(main_df_final.loc[main_df_final['left'] == 1])
# Out:
# 3571

# %%
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %% [markdown]
# ## Preparing our Dataset for Machine Learning

# %%
from sklearn.model_selection import train_test_split

# We remove the label values from our training data
X = main_df_final.drop(['left'],axis=1).values

# We assigned those label values to our Y dataset
y = main_df_final['left'].values

# %%
# Split it to a 70:30 Ratio Train:Test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Normalize the data
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
df_train = pd.DataFrame(X_train)
df_train.head()
# Out:
#          0         1         2   ...        15        16        17
# 0 -1.465811 -0.821091 -0.340223  ... -0.474133 -0.976558  1.152810
# 1 -1.465811  0.917363 -0.340223  ...  2.109115 -0.976558  1.152810
# 2 -1.465811 -1.300664 -0.340223  ... -0.474133 -0.976558  1.152810
# 3  0.156789 -0.641251  1.717381  ... -0.474133 -0.976558  1.152810
# 4 -0.654511 -0.681215 -1.026091  ...  2.109115 -0.976558 -0.867446
#
# [5 rows x 18 columns]

# %%
df_train.describe()
# Out:
#                  0             1   ...            16            17
# count  1.049900e+04  1.049900e+04  ...  1.049900e+04  1.049900e+04
# mean  -8.840332e-17 -1.167220e-16  ... -1.472952e-15  2.901659e-16
# std    1.000048e+00  1.000048e+00  ...  1.000048e+00  1.000048e+00
# min   -1.465811e+00 -2.099953e+00  ... -9.765581e-01 -8.674457e-01
# 25%   -6.545112e-01 -9.010197e-01  ... -9.765581e-01 -8.674457e-01
# 50%    1.567890e-01 -2.180173e-02  ... -9.765581e-01 -8.674457e-01
# 75%    9.680893e-01  8.773984e-01  ...  1.024005e+00  1.152810e+00
# max    2.590690e+00  2.176243e+00  ...  1.024005e+00  1.152810e+00
#
# [8 rows x 18 columns]

# %% [markdown]
# ## Let's Train a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 77.76%
# [[3146  250]
#  [ 751  353]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86      3396
#            1       0.59      0.32      0.41      1104
#
#     accuracy                           0.78      4500
#    macro avg       0.70      0.62      0.64      4500
# weighted avg       0.75      0.78      0.75      4500

# %% [markdown]
# ### Let's Try a Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
score = model.score(X_test, y_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 98.29%
# [[3384   12]
#  [  65 1039]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3396
#            1       0.99      0.94      0.96      1104
#
#     accuracy                           0.98      4500
#    macro avg       0.98      0.97      0.98      4500
# weighted avg       0.98      0.98      0.98      4500

# %%
hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
main_df_final.drop(['left'],axis=1).columns
# Out:
# Index(['number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'promotion_last_5years', 'satisfaction_level',
#        'last_evaluation', 'department_RandD', 'department_accounting',
#        'department_hr', 'department_management', 'department_marketing',
#        'department_product_mng', 'department_sales', 'department_support',
#        'department_technical', 'salary_low', 'salary_medium'],
#       dtype='object')

# %%
import pandas as pd
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = pd.DataFrame(X_train).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

feature_importances
# Out:
#     importance
# 5     0.297888
# 0     0.195369
# 2     0.182582
# 1     0.164363
# 6     0.118640
# 3     0.008820
# 16    0.007826
# 17    0.003602
# 15    0.003511
# 13    0.003085
# 14    0.002902
# 4     0.002102
# 9     0.001968
# 7     0.001760
# 8     0.001714
# 10    0.001627
# 12    0.001180
# 11    0.001061

# %% [markdown]
# ### Can Deep Learning Make a Difference?

# %%
# Use the newest version of TensorFlow 2.0
# %tensorflow_version 2.x

# %%
# If you wish to use Tensorflow 1.X run the following line and then restart runtime
# %tensorflow_version 1.x 
# You'll need to change your import statements from tensorflow.keras to keras
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(9, kernel_initializer = "uniform", activation = "relu", input_dim=18))
model.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))

model.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
# Display Model Summary and Show Parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 9)                 171
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 10
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Start Training Our Classifier 
batch_size = 10
epochs = 25

history = model.fit(X_train,
                    y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_data = (X_test, y_test))

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.4228 - accuracy: 0.7962 - val_loss: 0.3123 - val_accuracy: 0.8260
# Epoch 2/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2533 - accuracy: 0.8600 - val_loss: 0.2520 - val_accuracy: 0.9078
# Epoch 3/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2159 - accuracy: 0.9378 - val_loss: 0.2311 - val_accuracy: 0.9344
# Epoch 4/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1976 - accuracy: 0.9480 - val_loss: 0.2199 - val_accuracy: 0.9407
# Epoch 5/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1858 - accuracy: 0.9544 - val_loss: 0.2105 - val_accuracy: 0.9436
# Epoch 6/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1772 - accuracy: 0.9578 - val_loss: 0.2040 - val_accuracy: 0.9436
# Epoch 7/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1705 - accuracy: 0.9590 - val_loss: 0.2000 - val_accuracy: 0.9469
# Epoch 8/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1654 - accuracy: 0.9595 - val_loss: 0.1977 - val_accuracy: 0.9449
# Epoch 9/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1618 - accuracy: 0.9600 - val_loss: 0.1952 - val_accuracy: 0.9467
# Epoch 10/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1585 - accuracy: 0.9605 - val_loss: 0.1925 - val_accuracy: 0.9480
# Epoch 11/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1563 - accuracy: 0.9613 - val_loss: 0.1919 - val_accuracy: 0.9478
# Epoch 12/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1548 - accuracy: 0.9610 - val_loss: 0.1904 - val_accuracy: 0.9478
# Epoch 13/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1534 - accuracy: 0.9600 - val_loss: 0.1900 - val_accuracy: 0.9482
# Epoch 14/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1521 - accuracy: 0.9611 - val_loss: 0.1898 - val_accuracy: 0.9482
# Epoch 15/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1510 - accuracy: 0.9605 - val_loss: 0.1896 - val_accuracy: 0.9491
# Epoch 16/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1499 - accuracy: 0.9614 - val_loss: 0.1891 - val_accuracy: 0.9460
# Epoch 17/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1495 - accuracy: 0.9609 - val_loss: 0.1913 - val_accuracy: 0.9504
# Epoch 18/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1490 - accuracy: 0.9610 - val_loss: 0.1876 - val_accuracy: 0.9480
# Epoch 19/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1483 - accuracy: 0.9613 - val_loss: 0.1868 - val_accuracy: 0.9484
# Epoch 20/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1476 - accuracy: 0.9617 - val_loss: 0.1889 - val_accuracy: 0.9480
# Epoch 21/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1476 - accuracy: 0.9620 - val_loss: 0.1870 - val_accuracy: 0.9480
# Epoch 22/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1468 - accuracy: 0.9610 - val_loss: 0.1876 - val_accuracy: 0.9498
# Epoch 23/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1466 - accuracy: 0.9619 - val_loss: 0.1867 - val_accuracy: 0.9480
# Epoch 24/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1459 - accuracy: 0.9609 - val_loss: 0.1856 - val_accuracy: 0.9476
# Epoch 25/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1457 - accuracy: 0.9626 - val_loss: 0.1865 - val_accuracy: 0.9493
# Test loss: 0.18647734820842743
# Test accuracy: 0.9493333101272583

# %%
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Displaying the Classification Report and Confusion Matrix

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5)

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[3304   92]
#  [ 136  968]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      3396
#            1       0.91      0.88      0.89      1104
#
#     accuracy                           0.95      4500
#    macro avg       0.94      0.92      0.93      4500
# weighted avg       0.95      0.95      0.95      4500
